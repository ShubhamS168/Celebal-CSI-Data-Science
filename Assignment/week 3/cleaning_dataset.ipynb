# %%
import pandas as pd

# %%
df = pd.read_csv("ipl_2024.csv")

# df.columns
df.columns.tolist()
# Out:
# ['season',
#  'match_id',
#  'match_name',
#  'home_team',
#  'away_team',
#  'venue',
#  'city',
#  'country',
#  'current_innings',
#  'innings_id',
#  'name',
#  'fullName',
#  'runs',
#  'ballsFaced',
#  'minutes',
#  'fours',
#  'sixes',
#  'strikeRate',
#  'captain',
#  'isNotOut',
#  'runningScore',
#  'runningOver',
#  'shortText',
#  'commentary',
#  'link']

# %%
df.head(2)
# Out:
#    season  match_id match_name home_team away_team  \
# 0  2024.0   1422119  CSK v RCB       CSK       RCB
# 1  2024.0   1422119  CSK v RCB       CSK       RCB
#
#                                       venue     city country current_innings  \
# 0  MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India             RCB
# 1  MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India             RCB
#
#    innings_id  ... fours sixes  strikeRate  captain isNotOut  \
# 0           1  ...     0     1      105.00    False    False
# 1           1  ...     8     0      152.17     True    False
#
#                  runningScore  runningOver                       shortText  \
# 0  {'wickets': 4, 'runs': 77}         11.2  c Ravindra b Mustafizur Rahman
# 1  {'wickets': 1, 'runs': 41}          4.3  c Ravindra b Mustafizur Rahman
#
#                                           commentary  link
# 0  tiki-taka catch between Rahane and Ravindra at...   NaN
# ...

# %%
# df.drop(columns=['link'])

df.drop(columns=['link'], inplace=True)
# This removes the link column from df permanently.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 3
#       1 # df.drop(columns=['link'])
# ----> 3 df.drop(columns=['link'], inplace=True)
#       4 # This removes the link column from df permanently.
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
# ...

# %%
# Step 3: Save the updated DataFrame to a new CSV file
df.to_csv('IPL_cleaned_2024.csv', index=False)

# index=False gives you a cleaner CSV without unnecessary row numbers.

# %%
df.columns
# Out:
# Index(['season', 'match_id', 'match_name', 'home_team', 'away_team', 'venue',
#        'city', 'country', 'current_innings', 'innings_id', 'name', 'fullName',
#        'runs', 'ballsFaced', 'minutes', 'fours', 'sixes', 'strikeRate',
#        'captain', 'isNotOut', 'runningScore', 'runningOver', 'shortText',
#        'commentary'],
#       dtype='object')

# %%
df.describe()
#only column with numeric value
# Out:
#        season      match_id  innings_id        runs  ballsFaced       fours  \
# count   928.0  9.280000e+02  928.000000  928.000000  928.000000  928.000000
# mean   2024.0  1.424816e+06    1.495690   22.417026   14.733836    1.989224
# std       0.0  1.983394e+03    0.500251   23.264337   12.839531    2.400084
# min    2024.0  1.422119e+06    1.000000    0.000000    0.000000    0.000000
# 25%    2024.0  1.422133e+06    1.000000    5.000000    5.000000    0.000000
# 50%    2024.0  1.426268e+06    1.000000   15.000000   11.000000    1.000000
# 75%    2024.0  1.426283e+06    2.000000   33.000000   21.000000    3.000000
# max    2024.0  1.426297e+06    2.000000  124.000000   72.000000   14.000000
#
#             sixes  runningOver
# count  928.000000   723.000000
# mean     1.145474    11.077593
# std      1.710227     5.980800
# min      0.000000     0.100000
# 25%      0.000000     5.500000
# 50%      0.000000    12.100000
# 75%      2.000000    16.500000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 928 entries, 0 to 927
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   season           928 non-null    float64
#  1   match_id         928 non-null    int64
#  2   match_name       928 non-null    object
#  3   home_team        928 non-null    object
#  4   away_team        928 non-null    object
#  5   venue            928 non-null    object
#  6   city             928 non-null    object
#  7   country          928 non-null    object
#  8   current_innings  928 non-null    object
#  9   innings_id       928 non-null    int64
#  10  name             928 non-null    object
#  11  fullName         928 non-null    object
#  12  runs             928 non-null    int64
#  13  ballsFaced       928 non-null    int64
#  14  minutes          928 non-null    object
#  15  fours            928 non-null    int64
#  16  sixes            928 non-null    int64
# ...

# %%
df.shape
# Out:
# (928, 24)

# %%
df.name
# Out:
# 0           V Kohli
# 1      F du Plessis
# 2        RM Patidar
# 3        GJ Maxwell
# 4           C Green
#            ...
# 923          S Dube
# 924       RA Jadeja
# 925        MS Dhoni
# 926      MJ Santner
# 927       SN Thakur
# Name: name, Length: 928, dtype: object

# %%
df.rename(columns = {'name':'batsmen'}, inplace = True)

# %%
df.batsmen
# Out:
# 0           V Kohli
# 1      F du Plessis
# 2        RM Patidar
# 3        GJ Maxwell
# 4           C Green
#            ...
# 923          S Dube
# 924       RA Jadeja
# 925        MS Dhoni
# 926      MJ Santner
# 927       SN Thakur
# Name: batsmen, Length: 928, dtype: object

# %%
# to check i there any null value in any column or not
df.isnull().sum()
# Out:
# season               0
# match_id             0
# match_name           0
# home_team            0
# away_team            0
# venue                0
# city                 0
# country              0
# current_innings      0
# innings_id           0
# batsmen              0
# fullName             0
# runs                 0
# ballsFaced           0
# minutes              0
# fours                0
# sixes                0
# strikeRate           0
# captain              0
# isNotOut             0
# runningScore         0
# runningOver        205
# shortText            0
# commentary         205
# dtype: int64

# %%
df.dropna(inplace = True)

# %%
df.isnull().sum()
# there is no nullvalues in Company_Profile column
# Out:
# season             0
# match_id           0
# match_name         0
# home_team          0
# away_team          0
# venue              0
# city               0
# country            0
# current_innings    0
# innings_id         0
# batsmen            0
# fullName           0
# runs               0
# ballsFaced         0
# minutes            0
# fours              0
# sixes              0
# strikeRate         0
# captain            0
# isNotOut           0
# runningScore       0
# runningOver        0
# shortText          0
# commentary         0
# dtype: int64

# %%
df.head(5)
# Out:
#    season  match_id match_name home_team away_team  \
# 0  2024.0   1422119  CSK v RCB       CSK       RCB
# 1  2024.0   1422119  CSK v RCB       CSK       RCB
# 2  2024.0   1422119  CSK v RCB       CSK       RCB
# 3  2024.0   1422119  CSK v RCB       CSK       RCB
# 4  2024.0   1422119  CSK v RCB       CSK       RCB
#
#                                       venue     city country current_innings  \
# 0  MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India             RCB
# 1  MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India             RCB
# 2  MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India             RCB
# 3  MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India             RCB
# 4  MA Chidambaram Stadium, Chepauk, Chennai  Chennai   India             RCB
#
#    innings_id  ... minutes fours  sixes  strikeRate captain  isNotOut  \
# 0           1  ...      46     0      1      105.00   False     False
# ...
